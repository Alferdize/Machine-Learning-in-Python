# %%
import pandas as pd

# %%
df = pd.read_csv("nyc_weather.csv")

# %%
df = pd.read_excel("weather_data.xlsx")

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(weather_data, columns=["Date","Temperature","windspeed","Event"])

# %%
df
# Out:
#        Date  Temperature  windspeed  Event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#                                World 5,466,278  +68,328    345,592  +1,984  \
# 1  USA     1,677,258 +10,430  99,040      +357  451,176  1,127,042  17,155
# 2  Brazil  352,744   +5,346   22,291      +278  142,587    187,866   8,318
# 3  Russia  344,481   +8,599    3,541      +153  113,299    227,641   2,300
# 4  Spain   282,852   +482     28,752       +74  196,958     57,142     854
# 5  UK      259,559   +2,405   36,793      +118      NaN        NaN   1,559
# 6  Italy   229,858   +531     32,785       +50  140,479     56,594     553
# 7  France  182,584   +115     28,367       +35   64,617     89,600   1,655
# 8  Germany 180,219   +233      8,371        +5  160,300     11,548     889
# 9  Turkey  156,827   +1,141    4,340       +32  118,694     33,793     769
# 10 India   138,536   +7,113    4,024      +156   57,692     76,820   8,944
# 11 Iran    135,701   +2,180    7,417       +58  105,801     22,483   2,615
# 12 Peru    115,754   3,373    47,915    64,466      909      3,516     102
#
#                              2,287,641 2,833,045      53,208     701  \
# 1  USA     1,677,258 +10,430     5,070       299  14,635,920  44,244
# 2  Brazil  352,744   +5,346      1,661       105     735,224   3,461
# 3  Russia  344,481   +8,599      2,361        24   8,685,305  59,518
# 4  Spain   282,852   +482        6,050       615   3,556,567  76,071
# 5  UK      259,559   +2,405      3,826       542   3,458,905  50,979
# 6  Italy   229,858   +531        3,801       542   3,447,012  57,003
# 7  France  182,584   +115        2,798       435   1,384,633  21,218
# 8  Germany 180,219   +233        2,152       100   3,595,059  42,923
# 9  Turkey  156,827   +1,141      1,862        52   1,832,262  21,750
# 10 India   138,536   +7,113        100         3   2,943,421   2,135
# 11 Iran    135,701   +2,180      1,618        88     800,519   9,544
# 12 Peru    115,754   3,373     788,341    23,946  32,922,175    None
#
#                                        44.3
# 1  USA     1,677,258 +10,430    330,801,130
# 2  Brazil  352,744   +5,346     212,401,542
# 3  Russia  344,481   +8,599     145,928,144
# 4  Spain   282,852   +482        46,752,950
# 5  UK      259,559   +2,405      67,849,102
# 6  Italy   229,858   +531        60,470,714
# 7  France  182,584   +115        65,258,794
# 8  Germany 180,219   +233        83,756,505
# 9  Turkey  156,827   +1,141      84,242,466
# 10 India   138,536   +7,113   1,378,566,974
# 11 Iran    135,701   +2,180      83,877,328
# 12 Peru    115,754   3,373             None
