# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,3,4,5,6,7]
y = [5,6,3,4,3,5,4,6]
plt.scatter(x,y,label="skitscat", color="k",marker="*",s=100)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Scatter")
plt.legend()
